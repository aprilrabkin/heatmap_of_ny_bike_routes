# %%
import pandas as pd
import numpy as np

# %%
bikeData = pd.read_csv("/Users/aprilrabkin/Source/BikeShareHeatmap/201405-citibike-tripdata.csv")

# %%
bikeData.columns
# Out:
# Index([u'tripduration', u'starttime', u'stoptime', u'start station id', u'start station name', u'start station latitude', u'start station longitude', u'end station id', u'end station name', u'end station latitude', u'end station longitude', u'bikeid', u'usertype', u'birth year', u'gender'], dtype='object')

# %%
columns = []
for column in bikeData.columns:
    columns.append(column.replace(" ", '_'))

print columns
# Out:
# ['tripduration', 'starttime', 'stoptime', 'start_station_id', 'start_station_name', 'start_station_latitude', 'start_station_longitude', 'end_station_id', 'end_station_name', 'end_station_latitude', 'end_station_longitude', 'bikeid', 'usertype', 'birth_year', 'gender']

# %%
bikeData.columns = ['tripduration', 'starttime', 'stoptime', 'start_station_id', 'start_station_name', 'start_station_latitude', 'start_station_longitude', 'end_station_id', 'end_station_name', 'end_station_latitude', 'end_station_longitude', 'bikeid', 'usertype', 'birth_year', 'gender']

# %%
bikeData.columns
bikeData = bikeData[bikeData.start_station_id != bikeData.end_station_id]

# %%
dataGroupedByRoute = bikeData.groupby(["start_station_name","end_station_name","start_station_latitude", "start_station_longitude","end_station_latitude", "end_station_longitude"])
tripsPerRoute = dataGroupedByRoute.size().reset_index()
tripsPerRoute.sort(columns=0, ascending=False, inplace=True)
tripsPerRoute.columns = ["start_station_name","end_station_name","start_station_latitude", "start_station_longitude","end_station_latitude", "end_station_longitude","total_trips_in_May"]
tripsPerRoute.head(20)
# Out:
#                       start_station_name                   end_station_name  \
# 37131  Grand Army Plaza & Central Park S                 Broadway & W 60 St
# 2106                    12 Ave & W 40 St              West St & Chambers St
# 29013           E 42 St & Vanderbilt Ave                    W 33 St & 7 Ave
# 69113                     West Thames St           Vesey Pl & River Terrace
# 57937                    W 21 St & 6 Ave                    9 Ave & W 22 St
# 29492           E 43 St & Vanderbilt Ave                    W 41 St & 8 Ave
# 13385                 Broadway & W 60 St  Grand Army Plaza & Central Park S
# 67901                Washington Square E            University Pl & E 14 St
# 29020           E 42 St & Vanderbilt Ave                    W 41 St & 8 Ave
# 58134                    W 21 St & 6 Ave                   W 22 St & 10 Ave
# 20038                 E 10 St & Avenue A              Lafayette St & E 8 St
# ...

# %%
import polyline as polyline
from polyline.codec import PolylineCodec
PolylineCodec().decode('u{~vFvyys@fS]')
# Out:
# [(40.63179, -8.65708), (40.62855, -8.65693)]

# %%
import requests # pip install requests
import json

# %%
pd.set_option('display.max_colwidth', -1)

# %%
def make_api_call(url):
    return requests.get(url, verify=False).json()['routes'][0]['overview_polyline']['points']

# %%
path = 'https://maps.googleapis.com/maps/api/directions/json?origin='
OLD_API_key = "&key=AIzaSyBjMcKkWaRaXQHQwPp3oTvB3Z811u5wYFQ"
API_key = "&key=AIzaSyA9d1kAVmCXT8vw6mLwDM0EABDya9o2Dy0"

# %%
tripsPerRoute['end_station_latitude'] = tripsPerRoute['end_station_latitude'].astype(str)
tripsPerRoute['start_station_latitude'] = tripsPerRoute['start_station_latitude'].astype(str)
tripsPerRoute['start_station_longitude'] = tripsPerRoute['start_station_longitude'].astype(str)
tripsPerRoute['end_station_longitude'] = tripsPerRoute['end_station_longitude'].astype(str) 
tripsPerRoute.start_station_latitude[0]
# Out:
# '40.73221853'

# %%
tripsPerRoute['url'] = path + tripsPerRoute.start_station_latitude + "," + tripsPerRoute.start_station_longitude + "&destination=" + tripsPerRoute.end_station_latitude + "," + tripsPerRoute.end_station_longitude + "&mode=bicycling" + API_key

# %%
url_of_first_w_new_key = tripsPerRoute.head(1).url

# %%
url_of_first_w_new_key
# Out:
# 37131    https://maps.googleapis.com/maps/api/directions/json?origin=40.7643971,-73.97371465&destination=40.76915505,-73.98191841&mode=bicycling&key=AIzaSyA9d1kAVmCXT8vw6mLwDM0EABDya9o2Dy0
# Name: url, dtype: object

# %%
testGroup = tripsPerRoute.head(1)
print testGroup
testGroup['overview_polyline']= testGroup.url.map(lambda x: make_api_call(x) )
# Out:
# /Library/Python/2.7/site-packages/requests/packages/urllib3/connectionpool.py:769: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.org/en/latest/security.html
#   InsecureRequestWarning)
# -c:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                       start_station_name    end_station_name  \
# 37131  Grand Army Plaza & Central Park S  Broadway & W 60 St
#
#       start_station_latitude start_station_longitude end_station_latitude  \
# 37131  40.7643971             -73.97371465            40.76915505
#
#       end_station_longitude  total_trips_in_May  \
# 37131  -73.98191841          406
#
# ...

# %%
testGroup
# Out:
#                       start_station_name    end_station_name  \
# 37131  Grand Army Plaza & Central Park S  Broadway & W 60 St
#
#       start_station_latitude start_station_longitude end_station_latitude  \
# 37131  40.7643971             -73.97371465            40.76915505
#
#       end_station_longitude  total_trips_in_May  \
# 37131  -73.98191841          406
#
#                                                                                                                                                                                        url  \
# 37131  https://maps.googleapis.com/maps/api/directions/json?origin=40.7643971,-73.97371465&destination=40.76915505,-73.98191841&mode=bicycling&key=AIzaSyA9d1kAVmCXT8vw6mLwDM0EABDya9o2Dy0
#
#                                             overview_polyline
# 37131  qxxwF~~nbMa@W}EdOcAdDeEvM_ApCoA`EORe@n@I?]FUTk@`AIDoBD

# %%
tripsPerRoute = tripsPerRoute[0:150]

# %%
tripsPerRoute['overview_polyline'] = tripsPerRoute.url.map(lambda x: make_api_call(x) )
# Out:
# /Library/Python/2.7/site-packages/requests/packages/urllib3/connectionpool.py:769: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.org/en/latest/security.html
#   InsecureRequestWarning)
# /Library/Python/2.7/site-packages/requests/packages/urllib3/connectionpool.py:769: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.org/en/latest/security.html
#   InsecureRequestWarning)
# /Library/Python/2.7/site-packages/requests/packages/urllib3/connectionpool.py:769: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.org/en/latest/security.html
#   InsecureRequestWarning)
# ...

# %%
tripsPerRoute.tail(10).overview_polyline
# Out:
# 27984    ywuwFbmobMqObf@wKh]tBd@fFx@rARvCVdDXz@T|@j@B?Vu@V?yF~P
# 56874    iktwFdltbMaMj`@wDeCyCoBMIY~@Od@ENgCfI
# 28822    smvwFx{obMiCaBiAtDwKd]sEzNvCv@fH|A|GvAvEt@|BVfD\bBLf@Lf@Rj@`@HUPc@T@BBHDbALB@
# 3991     ehvwF`}rbMoZaSeOyJyFsDyFuDsNmJ[Q
# 5470     k~wwFxlrbMrGhEdEtCjCbBnJdG|@r@|@h@pEvCtDbCnClBzEbDf@sAnEgNyByA}FwD
# 3981     ehvwF`}rbM_KwGwFsD{ByAcDfKmArDcBpFGNm@hBuAfEUMYSECcAo@yB}A{@lCcCxHo@rBSM
# 4187     ehvwF`}rbM_KwG{ByAsFrPm@vBQj@M^W|@sCzI
# 51886    }mnwFlewbMEAGVI`@Ha@fHnB|Bz@hElCVy@
# 5730     wzjwF`snbM~TmCKlK[lQSlSKjI
# 15000    _bywFdnobMT?VFcAdDeEvM_ApCoA`EORe@n@I?Q@YNOVAFCf@Fj@N\FFPFR@^KLQHMDUB[?OVQJELA|AR
# Name: overview_polyline, dtype: object

# %%
tripsPerRoute['coords'] = ""
PolylineCodec().decode("")
# Out:
# []

# %%
tripsPerRoute['coords'] = tripsPerRoute.overview_polyline.map(lambda x:  PolylineCodec().decode(x) )

# %%
tripsPerRoute.head(1).coords
# Out:
# 37131    [(40.76441, -73.97376), (40.76458, -73.97364), (40.76569, -73.97623), (40.76603, -73.97706), (40.76702, -73.97942), (40.76734, -73.98015), (40.76774, -73.98112), (40.76782, -73.98122), (40.76801, -73.98146), (40.76806, -73.98146), (40.76821, -73.9815), (40.76832, -73.98161), (40.76854, -73.98194), (40.76859, -73.98197), (40.76915, -73.982)]
# Name: coords, dtype: object

# %%
coords_array = []
for cell in tripsPerRoute['coords']:
    for coord in cell:
        coords_array.append([coord[0], coord[1]])

# %%
coords_array
# Out:
# [[40.76441, -73.97376],
#  [40.76458, -73.97364],
#  [40.76569, -73.97623],
#  [40.76603, -73.97706],
#  [40.76702, -73.97942],
#  [40.76734, -73.98015],
#  [40.76774, -73.98112],
#  [40.76782, -73.98122],
#  [40.76801, -73.98146],
#  [40.76806, -73.98146],
#  [40.76821, -73.9815],
#  [40.76832, -73.98161],
#  [40.76854, -73.98194],
#  [40.76859, -73.98197],
#  [40.76915, -73.982],
#  [40.76085, -74.00277],
#  [40.76083, -74.00264],
#  [40.76081, -74.00254],
#  [40.76079, -74.00255],
#  [40.76065, -74.00261],
#  [40.76025, -74.0029],
#  [40.75959, -74.00338],
#  [40.75443, -74.00713],
#  [40.75416, -74.00729],
#  [40.75392, -74.0074],
#  [40.75076, -74.00859],
#  [40.75043, -74.00865],
#  [40.75015, -74.00865],
#  [40.74992, -74.00864],
#  [40.74975, -74.00861],
#  [40.74956, -74.00853],
#  [40.74944, -74.00854],
#  [40.74927, -74.0086],
#  [40.74921, -74.00862],
#  [40.74913, -74.00862],
#  [40.74905, -74.00859],
#  [40.74898, -74.00854],
#  [40.74881, -74.00842],
# ...

# %%
df = pd.DataFrame(data = coords_array)

# %%
df.to_csv('coords_array.csv',index=False,header=False)
